# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(20)

cities = ["Tehran", "Mashhad", "Isfahan", "Tabriz", "Shiraz", "Ahvaz"]
days = np.arange(1, 31)

all_data = []

for city in cities:
    temp = np.random.randint(15, 41, size=30)
    hum = np.random.randint(20, 81, size=30)
    rain = np.random.randint(0, 51, size=30)

    df_city = pd.DataFrame({
        "City": city,          
        "Day": days,
        "Temperature": temp,
        "Humidity": hum,
        "Rainfall": rain
    })

    all_data.append(df_city) 


df = pd.concat(all_data, ignore_index=True)
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
print("----------------show data frame---------")
display(df)
# Out:
#         City  Day  Temperature  Humidity  Rainfall
# 0     Tehran    1           18        39        33
# 1     Tehran    2           30        77        14
# 2     Tehran    3           24        50        42
# 3     Tehran    4           35        66        30
# 4     Tehran    5           26        52         3
# 5     Tehran    6           37        30        18
# 6     Tehran    7           22        63         6
# 7     Tehran    8           17        26        41
# 8     Tehran    9           15        31        22
# 9     Tehran   10           37        38        14
# 10    Tehran   11           23        23         4
# 11    Tehran   12           36        33        27
# 12    Tehran   13           34        37        11
# 13    Tehran   14           31        76         8
# 14    Tehran   15           21        63         6
# 15    Tehran   16           21        36        26
# 16    Tehran   17           31        38        15
# 17    Tehran   18           24        35        18
# 18    Tehran   19           20        46        14
# 19    Tehran   20           22        79        10
# 20    Tehran   21           20        27        42
# 21    Tehran   22           17        31        33
# 22    Tehran   23           21        74        21
# 23    Tehran   24           28        49        50
# 24    Tehran   25           26        65        17
# 25    Tehran   26           40        26        40
# 26    Tehran   27           18        34        18
# 27    Tehran   28           25        44        42
# 28    Tehran   29           26        38        20
# 29    Tehran   30           28        49        30
# 30   Mashhad    1           19        47        11
# 31   Mashhad    2           23        70         5
# 32   Mashhad    3           37        64         0
# 33   Mashhad    4           31        30        22
# 34   Mashhad    5           34        70        37
# 35   Mashhad    6           35        69         4
# 36   Mashhad    7           31        64        43
# 37   Mashhad    8           36        25        18
# 38   Mashhad    9           25        22         9
# 39   Mashhad   10           21        77        14
# 40   Mashhad   11           24        43        37
# 41   Mashhad   12           38        51        35
# 42   Mashhad   13           35        57        11
# 43   Mashhad   14           15        73        41
# 44   Mashhad   15           27        80        23
# 45   Mashhad   16           29        45        29
# 46   Mashhad   17           37        74        33
# 47   Mashhad   18           32        61         2
# 48   Mashhad   19           24        29        19
# 49   Mashhad   20           21        73        22
# 50   Mashhad   21           25        22        45
# 51   Mashhad   22           22        35        21
# 52   Mashhad   23           24        77        20
# 53   Mashhad   24           38        74        20
# 54   Mashhad   25           37        21        49
# 55   Mashhad   26           24        50        45
# 56   Mashhad   27           29        44        24
# 57   Mashhad   28           39        69        11
# 58   Mashhad   29           39        68         1
# 59   Mashhad   30           30        60        41
# 60   Isfahan    1           33        74        35
# 61   Isfahan    2           34        53        23
# 62   Isfahan    3           19        26        49
# 63   Isfahan    4           35        32        10
# 64   Isfahan    5           27        56        27
# 65   Isfahan    6           19        48        35
# 66   Isfahan    7           24        26        30
# 67   Isfahan    8           25        20        50
# 68   Isfahan    9           15        27         1
# 69   Isfahan   10           30        66        41
# 70   Isfahan   11           36        22        21
# 71   Isfahan   12           30        46         5
# 72   Isfahan   13           25        26         6
# 73   Isfahan   14           19        70        41
# 74   Isfahan   15           18        31         4
# 75   Isfahan   16           27        39        18
# 76   Isfahan   17           25        67        10
# 77   Isfahan   18           17        60         0
# 78   Isfahan   19           22        79        43
# 79   Isfahan   20           15        31         4
# 80   Isfahan   21           26        26        47
# 81   Isfahan   22           37        53        40
# 82   Isfahan   23           30        29        11
# 83   Isfahan   24           33        42        15
# 84   Isfahan   25           22        36        11
# 85   Isfahan   26           26        36         4
# 86   Isfahan   27           36        59        22
# 87   Isfahan   28           22        64         6
# 88   Isfahan   29           38        61        39
# 89   Isfahan   30           20        22        44
# 90    Tabriz    1           24        64        36
# 91    Tabriz    2           26        53         7
# 92    Tabriz    3           33        43        11
# 93    Tabriz    4           35        33        23
# 94    Tabriz    5           18        66        20
# 95    Tabriz    6           15        79        33
# 96    Tabriz    7           38        59        35
# 97    Tabriz    8           15        78        21
# 98    Tabriz    9           19        63        44
# 99    Tabriz   10           31        44         4
# 100   Tabriz   11           22        50         6
# 101   Tabriz   12           20        20        18
# 102   Tabriz   13           37        53        49
# 103   Tabriz   14           20        24        35
# 104   Tabriz   15           30        75        48
# 105   Tabriz   16           38        49        32
# 106   Tabriz   17           25        68        24
# 107   Tabriz   18           20        56        20
# 108   Tabriz   19           32        33         8
# 109   Tabriz   20           30        47         8
# 110   Tabriz   21           31        26        49
# 111   Tabriz   22           36        54        29
# 112   Tabriz   23           39        61        11
# 113   Tabriz   24           21        53        19
# 114   Tabriz   25           37        52        16
# 115   Tabriz   26           37        25         9
# 116   Tabriz   27           21        49        45
# 117   Tabriz   28           22        59        18
# 118   Tabriz   29           31        36         2
# 119   Tabriz   30           32        67        30
# 120   Shiraz    1           19        46        32
# 121   Shiraz    2           37        20         0
# 122   Shiraz    3           16        53        23
# 123   Shiraz    4           28        51         5
# 124   Shiraz    5           28        59        43
# 125   Shiraz    6           27        31        14
# 126   Shiraz    7           26        71         0
# 127   Shiraz    8           31        66        22
# 128   Shiraz    9           18        43        18
# 129   Shiraz   10           23        57        25
# 130   Shiraz   11           36        71        24
# 131   Shiraz   12           15        49         8
# 132   Shiraz   13           31        60        39
# 133   Shiraz   14           36        73        28
# 134   Shiraz   15           40        26        43
# 135   Shiraz   16           34        26        37
# 136   Shiraz   17           20        59        49
# 137   Shiraz   18           33        68        42
# 138   Shiraz   19           17        63        44
# 139   Shiraz   20           34        55         8
# 140   Shiraz   21           18        59        15
# 141   Shiraz   22           19        38        48
# 142   Shiraz   23           15        36         2
# 143   Shiraz   24           23        41        50
# 144   Shiraz   25           26        58        31
# 145   Shiraz   26           19        23         3
# 146   Shiraz   27           40        77        46
# 147   Shiraz   28           28        41        27
# 148   Shiraz   29           32        58         0
# 149   Shiraz   30           22        76        11
# 150    Ahvaz    1           36        46        18
# 151    Ahvaz    2           30        39        50
# 152    Ahvaz    3           29        58        20
# 153    Ahvaz    4           31        74        24
# 154    Ahvaz    5           30        73        25
# 155    Ahvaz    6           26        75        15
# 156    Ahvaz    7           22        41         1
# 157    Ahvaz    8           18        65        10
# 158    Ahvaz    9           30        42        46
# 159    Ahvaz   10           36        24         6
# 160    Ahvaz   11           23        80        12
# 161    Ahvaz   12           24        70        33
# 162    Ahvaz   13           27        70        34
# 163    Ahvaz   14           17        32         6
# 164    Ahvaz   15           32        51        16
# 165    Ahvaz   16           15        40        46
# 166    Ahvaz   17           34        70        25
# 167    Ahvaz   18           34        45        35
# 168    Ahvaz   19           22        24        28
# 169    Ahvaz   20           27        32         6
# 170    Ahvaz   21           38        74        18
# 171    Ahvaz   22           23        28        19
# 172    Ahvaz   23           29        62         2
# 173    Ahvaz   24           20        44        44
# 174    Ahvaz   25           36        61        50
# 175    Ahvaz   26           31        46        49
# 176    Ahvaz   27           19        59         9
# 177    Ahvaz   28           31        67        20
# 178    Ahvaz   29           17        69        42
# 179    Ahvaz   30           34        55         1
# -------------------first

# %%
#Question1-section3-Q1
print("""
      ----------Question1-section3-q1---------""")
avg_temp_per_city=df.groupby("City")["Temperature"].mean()
print("Average of Temperature for each city:",avg_temp_per_city)

avg_hum_per_city=df.groupby("City")["Humidity"].mean()
print("Average of Humidity for each city:",avg_hum_per_city)

avg_rain_per_city=df.groupby("City")["Rainfall"].mean()
print("Average of Rainfall for each city:",avg_rain_per_city)
# Out:
#       ----------Question1-section3-q1---------
# Average of Temperature for each city: City
# Ahvaz      27.366667
# Isfahan    26.166667
# Mashhad    29.366667
# Shiraz     26.366667
# Tabriz     27.833333
# Tehran     25.766667
# Name: Temperature, dtype: float64
# Average of Humidity for each city: City
# Ahvaz      53.866667
# Isfahan    44.233333
# Mashhad    54.800000
# Shiraz     51.800000
# Tabriz     51.300000
# Tehran     45.833333
# Name: Humidity, dtype: float64
# Average of Rainfall for each city: City
# Ahvaz      23.666667
# Isfahan    23.066667
# Mashhad    23.066667
# Shiraz     24.566667
# Tabriz     23.666667
# Tehran     22.500000
# Name: Rainfall, dtype: float64

# %%
#Question1-section3-Q2
print("""
      ----------Question1-section3-q2---------""")
max_temp=avg_temp_per_city.max()
hottest_city=avg_temp_per_city[avg_temp_per_city==max_temp].index[0]
print("The hottest city:",hottest_city,"Max temp:",max_temp)

min_temp=avg_temp_per_city.min()
coldest_city=avg_temp_per_city[avg_temp_per_city==min_temp].index[0]
print("The coldest city:",coldest_city,"Min temp:",min_temp)

print("""
      ----------Question1-section3-q3-----------""")

rain_above_10=df[df["Rainfall"]>10]
print("Count of rainy days:",len(rain_above_10))
#rain_above_10
# Out:
#       ----------Question1-section3-q2---------
# The hottest city: Mashhad Max temp: 29.366666666666667
# The coldest city: Tehran Min temp: 25.766666666666666
#
#       ----------Question1-section3-q3-----------
# Count of rainy days: 135

# %%
print("""
      ----------Question1-section4-----------""")

Isfahan_temp=df[df["City"]=="Isfahan"]["Temperature"]
Isfahan_hum=df[df["City"]=="Isfahan"]["Humidity"]

plt.scatter(Isfahan_temp,Isfahan_hum)
plt.title("Temperature and Humidity Relationship-Isfahan(30 Days)")
plt.xlabel("Temperature (°C)")
plt.ylabel("Humidity(%)")
plt.show()
print("""
      ----------Question1-section5-----------""")
print("No relationship between Temperature and Humidity")
# Out:
#       ----------Question1-section4-----------
#       ----------Question1-section5-----------
# No relationship between Temperature and Humidity

# %%
#Question2 csv file
